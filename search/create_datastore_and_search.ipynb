# %% [markdown]
# # Create a Vertex AI Datastore and Search Engine
#
# <table align="left">
#
#   <td>
#     <a href="https://colab.research.google.com/github/GoogleCloudPlatform/generative-ai/blob/main/search/create_datastore_and_search.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/colab-logo-32px.png" alt="Colab logo"> Run in Colab
#     </a>
#   </td>
#   <td>
#     <a href="https://github.com/GoogleCloudPlatform/generative-ai/blob/main/search/reate_datastore_and_search.ipynb">
#       <img src="https://cloud.google.com/ml-engine/images/github-logo-32px.png" alt="GitHub logo">
#       View on GitHub
#     </a>
#   </td>
#   <td>
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/GoogleCloudPlatform/generative-ai/blob/main/search/reate_datastore_and_search.ipynb">
#       <img src="https://lh3.googleusercontent.com/UiNooY4LUgW_oTvpsNhPpQzsstV5W8F7rYgxgGBD85cWJoLmrOzhVs_ksK_vgx40SHs7jCqkTkCk=e14-rj-sc0xffffff-h130-w32" alt="Vertex AI logo">
#       Open in Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# ---
#
#
# * Authors: Kara Greenfield
# * Created: 22 Nov 2023
#
# ---
#
# ## Objective
#
# This notebook shows how to create and populate a Vertex AI Datastore, how to create a Vertex Search Engine connected to that datastore, and how to submit queries through the search engine.

# %% [markdown]
# Services used in the notebook:
#
# - ✅ Vertex AI Search for document search and retrieval

# %% [markdown]
# ## Install pre-requisites
#
# If running in Colab install the pre-requisites into the runtime. Otherwise it is assumed that the notebook is running in Vertex AI Workbench.

# %%
! pip install google-cloud-aiplatform -q
! pip install google-cloud-discoveryengine -q
! pip install langchain -q

# %% [markdown]
# ---
# #### ⚠️ Do not forget to restart the kernel!
# ---

# %% [markdown]
# ## Authenticate
#
# If running in Colab authenticate with `google.colab.google.auth` otherwise assume that running on Vertex AI Workbench.

# %%
import sys

if "google.colab" in sys.modules:
    from google.colab import auth as google_auth

    google_auth.authenticate_user()

from google.auth import default
creds, _ = default()

# %% [markdown]
# ## Configure notebook environment

# %%
PROJECT_ID = "<PROJECT_ID>"

# Separate locations are used for the datastore and search engine vs the LLM, because vertexai can't be initialized in the global region
LOCATION = "global" 
LLM_LOCATION = "<LLM_LOCATION>"

# %%
PROJECT_ID = "learning-405915"
LOCATION = "global" # Replace with your data store location
LLM_LOCATION = "us-central1"

# %% [markdown]
# ## Create and Populate a Datastore

# %%
from google.cloud import discoveryengine_v1alpha

def create_data_store(data_store_name):
    # Create a client
    client = discoveryengine_v1alpha.DataStoreServiceClient()

    # Initialize request argument(s)
    data_store = discoveryengine_v1alpha.DataStore()
    data_store.display_name = data_store_name
    data_store.industry_vertical = "GENERIC"
    data_store.content_config = "CONTENT_REQUIRED"
    

    request = discoveryengine_v1alpha.CreateDataStoreRequest(
        parent=f"projects/{PROJECT_ID}/locations/{LOCATION}/collections/default_collection",
        data_store=data_store,
        data_store_id=data_store_name,
    )

    # Make the request
    # The try block is necessary to prevent execution from haulting due to an error being thrown when the datastore takes a while to instantiate
    try:
        operation = client.create_data_store(request=request)
        response = operation.result(timeout=90)
    except:
        print("long-running operation")

# %%
# The datastore name can only contain lowercase letters, numbers, and hyphens
DATASTORE_ID = "alphabet-contracts"

create_data_store(DATASTORE_ID)

# %%
from google.cloud import storage
storage_client = storage.Client()

def import_single_document(
    project_id: str,
    location: str,
    data_store_id: str,
    gcs_uri: str,
) -> str:
    #  For more information, refer to:
    # https://cloud.google.com/generative-ai-app-builder/docs/locations#specify_a_multi-region_for_your_data_store
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )

    # Create a client
    client = discoveryengine_v1alpha.DocumentServiceClient(client_options=client_options)

    # The full resource name of the search engine branch.
    # e.g. projects/{project}/locations/{location}/dataStores/{data_store_id}/branches/{branch}
    parent = client.branch_path(
        project=project_id,
        location=location,
        data_store=data_store_id,
        branch="default_branch",
    )

    request = discoveryengine_v1alpha.ImportDocumentsRequest(
        parent=parent,
        gcs_source=discoveryengine_v1alpha.GcsSource(
            input_uris=[gcs_uri], data_schema="content"
        ),
        # Options: `FULL`, `INCREMENTAL`
        reconciliation_mode=discoveryengine_v1alpha.ImportDocumentsRequest.ReconciliationMode.INCREMENTAL,
    )
    
    # Make the request
    operation = client.import_documents(request=request)

    print(f"Waiting for operation to complete: {operation.operation.name}")
    response = operation.result()

    # Once the operation is complete,
    # get information from operation metadata
    metadata = discoveryengine_v1alpha.ImportDocumentsMetadata(operation.metadata)

    # Handle the response
    print(response)
    print(metadata)

    return operation.operation.name


def import_documents(project_id: str,
    location: str,
    data_store_id: str,
    gcs_uri: str,):
    
    
    source_documents_gs_uri = "gs://cloud-samples-data/gen-app-builder/search/alphabet-investor-pdfs"
    bucket_name = source_documents_gs_uri.split('/')[2]
    bucket = storage_client.get_bucket(bucket_name)
    source_documents = list(bucket.list_blobs(prefix=source_documents_gs_uri[source_documents_gs_uri.find(bucket_name) + len(bucket_name) + 1:]))
    
    for doc in source_documents:
        gsu = f'gs://{bucket.name}/{doc.name}'
        import_single_document(project_id, location, data_store_id, gsu)

# %%
source_documents_gs_uri = "cloud-samples-data/gen-app-builder/search/alphabet-investor-pdfs"

import_documents(PROJECT_ID, LOCATION, DATASTORE_ID, source_documents_gs_uri)
# Out:
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13165973765131656714
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13165973765131656769"
# }
#
# create_time {
#   seconds: 1700710067
#   nanos: 698322000
# }
# update_time {
#   seconds: 1700710068
#   nanos: 987636000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15353831033435618437
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15353831033435618422"
# }
#
# create_time {
#   seconds: 1700710070
#   nanos: 860566000
# }
# update_time {
#   seconds: 1700710071
#   nanos: 899856000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6156914448482241267
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6156914448482240958"
# }
#
# create_time {
#   seconds: 1700710073
#   nanos: 281216000
# }
# update_time {
#   seconds: 1700710074
#   nanos: 486303000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14028575834465262545
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14028575834465259862"
# }
#
# create_time {
#   seconds: 1700710075
#   nanos: 362336000
# }
# update_time {
#   seconds: 1700710076
#   nanos: 594676000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4254522594109523406
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4254522594109524307"
# }
#
# create_time {
#   seconds: 1700710078
#   nanos: 101226000
# }
# update_time {
#   seconds: 1700710079
#   nanos: 338524000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5429229802240406814
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5429229802240407481"
# }
#
# create_time {
#   seconds: 1700710080
#   nanos: 507956000
# }
# update_time {
#   seconds: 1700710081
#   nanos: 725620000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15593197617471234414
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15593197617471237237"
# }
#
# create_time {
#   seconds: 1700710083
#   nanos: 509924000
# }
# update_time {
#   seconds: 1700710084
#   nanos: 655520000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9583207213207963809
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9583207213207963616"
# }
#
# create_time {
#   seconds: 1700710085
#   nanos: 555543000
# }
# update_time {
#   seconds: 1700710086
#   nanos: 581615000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18037455476621131280
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18037455476621130381"
# }
#
# create_time {
#   seconds: 1700710088
#   nanos: 44914000
# }
# update_time {
#   seconds: 1700710089
#   nanos: 429324000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2946092419057740114
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2946092419057741723"
# }
#
# create_time {
#   seconds: 1700710090
#   nanos: 243735000
# }
# update_time {
#   seconds: 1700710091
#   nanos: 385151000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3255457247986537759
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3255457247986540016"
# }
#
# create_time {
#   seconds: 1700710092
#   nanos: 858234000
# }
# update_time {
#   seconds: 1700710094
#   nanos: 348688000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1475499946576041441
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1475499946576042570"
# }
#
# create_time {
#   seconds: 1700710095
#   nanos: 707641000
# }
# update_time {
#   seconds: 1700710096
#   nanos: 837892000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8884284402611724622
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8884284402611726803"
# }
#
# create_time {
#   seconds: 1700710097
#   nanos: 999677000
# }
# update_time {
#   seconds: 1700710099
#   nanos: 161586000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12796528007943344071
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12796528007943344072"
# }
#
# create_time {
#   seconds: 1700710100
#   nanos: 479368000
# }
# update_time {
#   seconds: 1700710101
#   nanos: 459651000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16504514001688242226
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16504514001688241551"
# }
#
# create_time {
#   seconds: 1700710102
#   nanos: 719667000
# }
# update_time {
#   seconds: 1700710103
#   nanos: 841613000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12796528007943340943
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12796528007943340944"
# }
#
# create_time {
#   seconds: 1700710105
#   nanos: 61142000
# }
# update_time {
#   seconds: 1700710106
#   nanos: 286434000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1668332606596349568
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1668332606596347307"
# }
#
# create_time {
#   seconds: 1700710107
#   nanos: 193217000
# }
# update_time {
#   seconds: 1700710108
#   nanos: 462456000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2576815642597473951
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2576815642597473858"
# }
#
# create_time {
#   seconds: 1700710111
#   nanos: 60881000
# }
# update_time {
#   seconds: 1700710112
#   nanos: 125281000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18162998288615272436
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18162998288615269949"
# }
#
# create_time {
#   seconds: 1700710113
#   nanos: 47795000
# }
# update_time {
#   seconds: 1700710114
#   nanos: 321215000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15473430135115302205
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15473430135115302656"
# }
#
# create_time {
#   seconds: 1700710115
#   nanos: 609985000
# }
# update_time {
#   seconds: 1700710116
#   nanos: 603569000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5429229802240407527
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5429229802240408194"
# }
#
# create_time {
#   seconds: 1700710117
#   nanos: 652309000
# }
# update_time {
#   seconds: 1700710118
#   nanos: 888929000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-33556504838251183
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors33556504838251570"
# }
#
# create_time {
#   seconds: 1700710120
#   nanos: 630974000
# }
# update_time {
#   seconds: 1700710121
#   nanos: 838147000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11283067823430635275
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11283067823430635276"
# }
#
# create_time {
#   seconds: 1700710123
#   nanos: 801155000
# }
# update_time {
#   seconds: 1700710125
#   nanos: 102620000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15965993144098228431
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15965993144098227288"
# }
#
# create_time {
#   seconds: 1700710126
#   nanos: 224001000
# }
# update_time {
#   seconds: 1700710127
#   nanos: 282846000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8982435569454773286
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8982435569454775199"
# }
#
# create_time {
#   seconds: 1700710128
#   nanos: 276004000
# }
# update_time {
#   seconds: 1700710129
#   nanos: 765025000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6487464103687281771
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6487464103687281536"
# }
#
# create_time {
#   seconds: 1700710131
#   nanos: 873528000
# }
# update_time {
#   seconds: 1700710132
#   nanos: 876811000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14721471271657814750
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14721471271657814077"
# }
#
# create_time {
#   seconds: 1700710134
#   nanos: 361441000
# }
# update_time {
#   seconds: 1700710135
#   nanos: 687182000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9812261496243538999
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9812261496243539024"
# }
#
# create_time {
#   seconds: 1700710136
#   nanos: 899605000
# }
# update_time {
#   seconds: 1700710138
#   nanos: 352726000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16555441856958407819
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16555441856958408748"
# }
#
# create_time {
#   seconds: 1700710140
#   nanos: 881305000
# }
# update_time {
#   seconds: 1700710141
#   nanos: 904275000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3936495126272514073
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3936495126272513044"
# }
#
# create_time {
#   seconds: 1700710142
#   nanos: 687626000
# }
# update_time {
#   seconds: 1700710143
#   nanos: 710800000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1829940367385673830
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1829940367385677445"
# }
#
# create_time {
#   seconds: 1700710144
#   nanos: 702395000
# }
# update_time {
#   seconds: 1700710145
#   nanos: 753271000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12386270627271380762
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12386270627271378873"
# }
#
# create_time {
#   seconds: 1700710147
#   nanos: 819541000
# }
# update_time {
#   seconds: 1700710149
#   nanos: 32374000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3935518617550341292
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3935518617550343321"
# }
#
# create_time {
#   seconds: 1700710151
#   nanos: 639832000
# }
# update_time {
#   seconds: 1700710152
#   nanos: 746280000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1998791717938656980
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1998791717938656869"
# }
#
# create_time {
#   seconds: 1700710155
#   nanos: 349831000
# }
# update_time {
#   seconds: 1700710156
#   nanos: 598467000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9233372439870506559
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9233372439870508784"
# }
#
# create_time {
#   seconds: 1700710157
#   nanos: 614122000
# }
# update_time {
#   seconds: 1700710158
#   nanos: 753365000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-815128394251563478
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors815128394251565381"
# }
#
# create_time {
#   seconds: 1700710159
#   nanos: 621192000
# }
# update_time {
#   seconds: 1700710160
#   nanos: 766733000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5143233016174778552
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5143233016174777549"
# }
#
# create_time {
#   seconds: 1700710161
#   nanos: 629393000
# }
# update_time {
#   seconds: 1700710162
#   nanos: 868199000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13407989433321200152
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13407989433321198827"
# }
#
# create_time {
#   seconds: 1700710163
#   nanos: 718267000
# }
# update_time {
#   seconds: 1700710164
#   nanos: 869507000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11976956702371189568
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11976956702371192677"
# }
#
# create_time {
#   seconds: 1700710166
#   nanos: 484181000
# }
# update_time {
#   seconds: 1700710167
#   nanos: 559673000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2900389839735219637
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2900389839735221472"
# }
#
# create_time {
#   seconds: 1700710169
#   nanos: 216234000
# }
# update_time {
#   seconds: 1700710170
#   nanos: 517178000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2900389839735221923
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2900389839735219662"
# }
#
# create_time {
#   seconds: 1700710171
#   nanos: 256176000
# }
# update_time {
#   seconds: 1700710172
#   nanos: 819311000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1024343001493960978
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1024343001493962187"
# }
#
# create_time {
#   seconds: 1700710173
#   nanos: 843101000
# }
# update_time {
#   seconds: 1700710175
#   nanos: 154761000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7236438040906767066
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7236438040906765813"
# }
#
# create_time {
#   seconds: 1700710176
#   nanos: 953469000
# }
# update_time {
#   seconds: 1700710178
#   nanos: 117672000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16629996815792277375
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16629996815792279378"
# }
#
# create_time {
#   seconds: 1700710179
#   nanos: 213673000
# }
# update_time {
#   seconds: 1700710180
#   nanos: 200965000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11254374557983636672
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11254374557983637393"
# }
#
# create_time {
#   seconds: 1700710181
#   nanos: 638737000
# }
# update_time {
#   seconds: 1700710182
#   nanos: 749087000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11284571364104510298
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11284571364104508571"
# }
#
# create_time {
#   seconds: 1700710184
#   nanos: 483166000
# }
# update_time {
#   seconds: 1700710185
#   nanos: 614436000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13893727330952983979
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13893727330952984320"
# }
#
# create_time {
#   seconds: 1700710186
#   nanos: 777795000
# }
# update_time {
#   seconds: 1700710187
#   nanos: 938225000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16629996815792278722
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16629996815792276629"
# }
#
# create_time {
#   seconds: 1700710189
#   nanos: 826909000
# }
# update_time {
#   seconds: 1700710190
#   nanos: 895388000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-10051208446881571380
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors10051208446881572553"
# }
#
# create_time {
#   seconds: 1700710192
#   nanos: 742997000
# }
# update_time {
#   seconds: 1700710194
#   nanos: 186762000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14028575834465260704
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14028575834465262117"
# }
#
# create_time {
#   seconds: 1700710197
#   nanos: 597798000
# }
# update_time {
#   seconds: 1700710198
#   nanos: 704447000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4944982250288167186
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4944982250288165111"
# }
#
# create_time {
#   seconds: 1700710199
#   nanos: 581131000
# }
# update_time {
#   seconds: 1700710200
#   nanos: 661877000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9377806008655556505
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9377806008655554640"
# }
#
# create_time {
#   seconds: 1700710201
#   nanos: 757323000
# }
# update_time {
#   seconds: 1700710202
#   nanos: 929979000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-17812317698740499753
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17812317698740499698"
# }
#
# create_time {
#   seconds: 1700710203
#   nanos: 841079000
# }
# update_time {
#   seconds: 1700710205
#   nanos: 167431000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2920227278357420562
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2920227278357421613"
# }
#
# create_time {
#   seconds: 1700710206
#   nanos: 29522000
# }
# update_time {
#   seconds: 1700710207
#   nanos: 543484000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18379683769668606016
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18379683769668606767"
# }
#
# create_time {
#   seconds: 1700710208
#   nanos: 462396000
# }
# update_time {
#   seconds: 1700710209
#   nanos: 857477000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-2900389839735218358
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors2900389839735220193"
# }
#
# create_time {
#   seconds: 1700710211
#   nanos: 18762000
# }
# update_time {
#   seconds: 1700710212
#   nanos: 26225000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5146008457709730205
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5146008457709731304"
# }
#
# create_time {
#   seconds: 1700710212
#   nanos: 890116000
# }
# update_time {
#   seconds: 1700710213
#   nanos: 898482000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13893727330952985862
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13893727330952986203"
# }
#
# create_time {
#   seconds: 1700710214
#   nanos: 599386000
# }
# update_time {
#   seconds: 1700710215
#   nanos: 710579000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7575105610135954792
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7575105610135955835"
# }
#
# create_time {
#   seconds: 1700710218
#   nanos: 854544000
# }
# update_time {
#   seconds: 1700710219
#   nanos: 917522000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8502808925360634548
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8502808925360633209"
# }
#
# create_time {
#   seconds: 1700710220
#   nanos: 919347000
# }
# update_time {
#   seconds: 1700710221
#   nanos: 982950000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8502808925360631952
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8502808925360634709"
# }
#
# create_time {
#   seconds: 1700710222
#   nanos: 727470000
# }
# update_time {
#   seconds: 1700710223
#   nanos: 926777000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12804963627923319294
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12804963627923320725"
# }
#
# create_time {
#   seconds: 1700710224
#   nanos: 864521000
# }
# update_time {
#   seconds: 1700710226
#   nanos: 141483000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7575105610135957168
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7575105610135954115"
# }
#
# create_time {
#   seconds: 1700710227
#   nanos: 708730000
# }
# update_time {
#   seconds: 1700710229
#   nanos: 35140000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7717870105708518318
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7717870105708517087"
# }
#
# create_time {
#   seconds: 1700710232
#   nanos: 445525000
# }
# update_time {
#   seconds: 1700710233
#   nanos: 669547000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9377806008655555883
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9377806008655554018"
# }
#
# create_time {
#   seconds: 1700710234
#   nanos: 511489000
# }
# update_time {
#   seconds: 1700710235
#   nanos: 671440000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12804963627923318352
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12804963627923319783"
# }
#
# create_time {
#   seconds: 1700710237
#   nanos: 299571000
# }
# update_time {
#   seconds: 1700710238
#   nanos: 392943000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11152748482315992963
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11152748482315990444"
# }
#
# create_time {
#   seconds: 1700710240
#   nanos: 81580000
# }
# update_time {
#   seconds: 1700710241
#   nanos: 208484000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6282419823366082985
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6282419823366084218"
# }
#
# create_time {
#   seconds: 1700710242
#   nanos: 369601000
# }
# update_time {
#   seconds: 1700710243
#   nanos: 400698000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-10047818168450841438
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors10047818168450841053"
# }
#
# create_time {
#   seconds: 1700710244
#   nanos: 837077000
# }
# update_time {
#   seconds: 1700710245
#   nanos: 889468000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3412173630274701675
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3412173630274701162"
# }
#
# create_time {
#   seconds: 1700710247
#   nanos: 858480000
# }
# update_time {
#   seconds: 1700710248
#   nanos: 947094000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16555441856958410083
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16555441856958406916"
# }
#
# create_time {
#   seconds: 1700710250
#   nanos: 27588000
# }
# update_time {
#   seconds: 1700710251
#   nanos: 160079000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14455729811491739690
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14455729811491741493"
# }
#
# create_time {
#   seconds: 1700710252
#   nanos: 172050000
# }
# update_time {
#   seconds: 1700710253
#   nanos: 226287000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15594887071998720943
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15594887071998718836"
# }
#
# create_time {
#   seconds: 1700710254
#   nanos: 248843000
# }
# update_time {
#   seconds: 1700710255
#   nanos: 359813000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16096488262366615852
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16096488262366615841"
# }
#
# create_time {
#   seconds: 1700710256
#   nanos: 255817000
# }
# update_time {
#   seconds: 1700710257
#   nanos: 449341000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5120818394571565604
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5120818394571565453"
# }
#
# create_time {
#   seconds: 1700710259
#   nanos: 248683000
# }
# update_time {
#   seconds: 1700710260
#   nanos: 301441000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8502808925360633224
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8502808925360631885"
# }
#
# create_time {
#   seconds: 1700710261
#   nanos: 28089000
# }
# update_time {
#   seconds: 1700710262
#   nanos: 144335000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9377806008655553939
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9377806008655556170"
# }
#
# create_time {
#   seconds: 1700710263
#   nanos: 4581000
# }
# update_time {
#   seconds: 1700710264
#   nanos: 22481000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7298049122373785700
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7298049122373783933"
# }
#
# create_time {
#   seconds: 1700710264
#   nanos: 786044000
# }
# update_time {
#   seconds: 1700710266
#   nanos: 530550000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18229597868701701172
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18229597868701700531"
# }
#
# create_time {
#   seconds: 1700710267
#   nanos: 717866000
# }
# update_time {
#   seconds: 1700710269
#   nanos: 276438000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3412173630274701791
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3412173630274701278"
# }
#
# create_time {
#   seconds: 1700710272
#   nanos: 714153000
# }
# update_time {
#   seconds: 1700710273
#   nanos: 740560000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15594887071998721033
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15594887071998718926"
# }
#
# create_time {
#   seconds: 1700710274
#   nanos: 721373000
# }
# update_time {
#   seconds: 1700710275
#   nanos: 785293000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3412173630274702483
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3412173630274701970"
# }
#
# create_time {
#   seconds: 1700710276
#   nanos: 646914000
# }
# update_time {
#   seconds: 1700710277
#   nanos: 645208000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9959290414993009032
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9959290414993010157"
# }
#
# create_time {
#   seconds: 1700710279
#   nanos: 100464000
# }
# update_time {
#   seconds: 1700710280
#   nanos: 129888000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-17998910133043184501
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17998910133043183844"
# }
#
# create_time {
#   seconds: 1700710282
#   nanos: 807752000
# }
# update_time {
#   seconds: 1700710283
#   nanos: 998572000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7329654086443471127
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7329654086443472498"
# }
#
# create_time {
#   seconds: 1700710285
#   nanos: 6433000
# }
# update_time {
#   seconds: 1700710286
#   nanos: 186493000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11152748482315992527
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11152748482315990008"
# }
#
# create_time {
#   seconds: 1700710287
#   nanos: 536194000
# }
# update_time {
#   seconds: 1700710288
#   nanos: 673146000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14439912332489352481
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14439912332489352618"
# }
#
# create_time {
#   seconds: 1700710289
#   nanos: 399925000
# }
# update_time {
#   seconds: 1700710290
#   nanos: 462810000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9671150683002847507
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9671150683002849610"
# }
#
# create_time {
#   seconds: 1700710292
#   nanos: 578762000
# }
# update_time {
#   seconds: 1700710293
#   nanos: 658439000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16096488262366616508
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16096488262366616497"
# }
#
# create_time {
#   seconds: 1700710294
#   nanos: 977298000
# }
# update_time {
#   seconds: 1700710296
#   nanos: 126543000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14593940370166276486
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14593940370166276797"
# }
#
# create_time {
#   seconds: 1700710297
#   nanos: 696420000
# }
# update_time {
#   seconds: 1700710298
#   nanos: 850719000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8339376422265561933
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8339376422265562830"
# }
#
# create_time {
#   seconds: 1700710299
#   nanos: 977572000
# }
# update_time {
#   seconds: 1700710301
#   nanos: 106854000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5686404386659436653
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5686404386659435172"
# }
#
# create_time {
#   seconds: 1700710302
#   nanos: 452556000
# }
# update_time {
#   seconds: 1700710303
#   nanos: 651904000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15248955167093077706
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15248955167093079339"
# }
#
# create_time {
#   seconds: 1700710304
#   nanos: 472813000
# }
# update_time {
#   seconds: 1700710305
#   nanos: 464591000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11976956702371189417
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11976956702371192526"
# }
#
# create_time {
#   seconds: 1700710306
#   nanos: 428778000
# }
# update_time {
#   seconds: 1700710307
#   nanos: 550467000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-16050054502903231860
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors16050054502903234341"
# }
#
# create_time {
#   seconds: 1700710308
#   nanos: 759885000
# }
# update_time {
#   seconds: 1700710309
#   nanos: 879316000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18052095643307291461
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18052095643307294228"
# }
#
# create_time {
#   seconds: 1700710311
#   nanos: 797381000
# }
# update_time {
#   seconds: 1700710313
#   nanos: 90305000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-17216287935097829295
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17216287935097828434"
# }
#
# create_time {
#   seconds: 1700710313
#   nanos: 807208000
# }
# update_time {
#   seconds: 1700710314
#   nanos: 835942000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18052095643307294122
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18052095643307292793"
# }
#
# create_time {
#   seconds: 1700710316
#   nanos: 558939000
# }
# update_time {
#   seconds: 1700710317
#   nanos: 877242000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12240176928768156243
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12240176928768157472"
# }
#
# create_time {
#   seconds: 1700710318
#   nanos: 676899000
# }
# update_time {
#   seconds: 1700710319
#   nanos: 910008000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4050648676039967271
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4050648676039969440"
# }
#
# create_time {
#   seconds: 1700710321
#   nanos: 363953000
# }
# update_time {
#   seconds: 1700710322
#   nanos: 619114000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9959290414993007514
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9959290414993008639"
# }
#
# create_time {
#   seconds: 1700710324
#   nanos: 229677000
# }
# update_time {
#   seconds: 1700710325
#   nanos: 250791000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11534053868315967633
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11534053868315970452"
# }
#
# create_time {
#   seconds: 1700710327
#   nanos: 76557000
# }
# update_time {
#   seconds: 1700710328
#   nanos: 291064000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11584358181806950388
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11584358181806951521"
# }
#
# create_time {
#   seconds: 1700710329
#   nanos: 372039000
# }
# update_time {
#   seconds: 1700710330
#   nanos: 529097000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11358479954965019091
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11358479954965018080"
# }
#
# create_time {
#   seconds: 1700710333
#   nanos: 414099000
# }
# update_time {
#   seconds: 1700710334
#   nanos: 554722000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5120818394571566498
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5120818394571566347"
# }
#
# create_time {
#   seconds: 1700710335
#   nanos: 305188000
# }
# update_time {
#   seconds: 1700710336
#   nanos: 379216000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5120818394571565245
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5120818394571565094"
# }
#
# create_time {
#   seconds: 1700710337
#   nanos: 112314000
# }
# update_time {
#   seconds: 1700710338
#   nanos: 316919000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9959290414993008267
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9959290414993009392"
# }
#
# create_time {
#   seconds: 1700710340
#   nanos: 367492000
# }
# update_time {
#   seconds: 1700710341
#   nanos: 557539000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1920525199796610624
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1920525199796613049"
# }
#
# create_time {
#   seconds: 1700710343
#   nanos: 2860000
# }
# update_time {
#   seconds: 1700710344
#   nanos: 30476000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-17001197231298617044
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17001197231298616381"
# }
#
# create_time {
#   seconds: 1700710345
#   nanos: 737899000
# }
# update_time {
#   seconds: 1700710346
#   nanos: 747089000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-696675740981947397
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors696675740981947170"
# }
#
# create_time {
#   seconds: 1700710347
#   nanos: 956645000
# }
# update_time {
#   seconds: 1700710349
#   nanos: 227692000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-3588336607307279635
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors3588336607307279274"
# }
#
# create_time {
#   seconds: 1700710350
#   nanos: 806338000
# }
# update_time {
#   seconds: 1700710351
#   nanos: 947417000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4505060627945745716
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4505060627945744847"
# }
#
# create_time {
#   seconds: 1700710354
#   nanos: 91698000
# }
# update_time {
#   seconds: 1700710355
#   nanos: 198891000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6766127689684284967
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6766127689684285874"
# }
#
# create_time {
#   seconds: 1700710356
#   nanos: 892417000
# }
# update_time {
#   seconds: 1700710358
#   nanos: 157017000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1660314122846304031
# error_config {
# ...
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17542596743687043961"
# }
#
# create_time {
#   seconds: 1700710413
#   nanos: 713696000
# }
# update_time {
#   seconds: 1700710414
#   nanos: 812685000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-1024343001493959465
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors1024343001493960674"
# }
#
# create_time {
#   seconds: 1700710415
#   nanos: 813218000
# }
# update_time {
#   seconds: 1700710416
#   nanos: 850910000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-389764771248499973
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors389764771248500266"
# }
#
# create_time {
#   seconds: 1700710418
#   nanos: 481265000
# }
# update_time {
#   seconds: 1700710419
#   nanos: 545739000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11958196643818996732
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11958196643818999633"
# }
#
# create_time {
#   seconds: 1700710420
#   nanos: 421350000
# }
# update_time {
#   seconds: 1700710421
#   nanos: 503603000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-10481428777141277499
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors10481428777141279810"
# }
#
# create_time {
#   seconds: 1700710422
#   nanos: 790170000
# }
# update_time {
#   seconds: 1700710423
#   nanos: 799887000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6195633437831978808
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6195633437831978325"
# }
#
# create_time {
#   seconds: 1700710425
#   nanos: 6201000
# }
# update_time {
#   seconds: 1700710426
#   nanos: 144224000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-9231863457065687760
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors9231863457065688767"
# }
#
# create_time {
#   seconds: 1700710426
#   nanos: 973796000
# }
# update_time {
#   seconds: 1700710428
#   nanos: 254622000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-10165367105076108736
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors10165367105076106625"
# }
#
# create_time {
#   seconds: 1700710429
#   nanos: 294390000
# }
# update_time {
#   seconds: 1700710430
#   nanos: 402247000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7119326982199467808
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7119326982199466783"
# }
#
# create_time {
#   seconds: 1700710433
#   nanos: 213138000
# }
# update_time {
#   seconds: 1700710434
#   nanos: 249973000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-688110595498082096
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors688110595498080743"
# }
#
# create_time {
#   seconds: 1700710435
#   nanos: 938030000
# }
# update_time {
#   seconds: 1700710437
#   nanos: 29071000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-5618741490281174568
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors5618741490281173099"
# }
#
# create_time {
#   seconds: 1700710438
#   nanos: 81502000
# }
# update_time {
#   seconds: 1700710439
#   nanos: 166407000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11228978429647142430
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11228978429647142245"
# }
#
# create_time {
#   seconds: 1700710439
#   nanos: 919098000
# }
# update_time {
#   seconds: 1700710440
#   nanos: 922482000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-8284412899020194547
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors8284412899020196452"
# }
#
# create_time {
#   seconds: 1700710442
#   nanos: 654902000
# }
# update_time {
#   seconds: 1700710443
#   nanos: 788799000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-760292820124130777
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors760292820124130774"
# }
#
# create_time {
#   seconds: 1700710445
#   nanos: 357645000
# }
# update_time {
#   seconds: 1700710446
#   nanos: 572173000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13532112274731023189
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13532112274731021444"
# }
#
# create_time {
#   seconds: 1700710448
#   nanos: 214464000
# }
# update_time {
#   seconds: 1700710449
#   nanos: 382873000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11228978429647142151
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11228978429647141966"
# }
#
# create_time {
#   seconds: 1700710451
#   nanos: 249245000
# }
# update_time {
#   seconds: 1700710452
#   nanos: 336771000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4280389400906656433
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4280389400906656060"
# }
#
# create_time {
#   seconds: 1700710454
#   nanos: 326661000
# }
# update_time {
#   seconds: 1700710455
#   nanos: 357780000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-40888181689039561
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors40888181689039534"
# }
#
# create_time {
#   seconds: 1700710456
#   nanos: 846249000
# }
# update_time {
#   seconds: 1700710457
#   nanos: 973808000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-6473944787623556180
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors6473944787623556825"
# }
#
# create_time {
#   seconds: 1700710460
#   nanos: 849646000
# }
# update_time {
#   seconds: 1700710461
#   nanos: 947611000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7640633846622505667
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7640633846622504456"
# }
#
# create_time {
#   seconds: 1700710463
#   nanos: 304973000
# }
# update_time {
#   seconds: 1700710464
#   nanos: 278970000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-12068422425675428836
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors12068422425675430455"
# }
#
# create_time {
#   seconds: 1700710466
#   nanos: 567169000
# }
# update_time {
#   seconds: 1700710467
#   nanos: 657905000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-7119326982199465598
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors7119326982199464573"
# }
#
# create_time {
#   seconds: 1700710469
#   nanos: 638062000
# }
# update_time {
#   seconds: 1700710470
#   nanos: 730403000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13286369372838551483
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13286369372838551240"
# }
#
# create_time {
#   seconds: 1700710472
#   nanos: 421876000
# }
# update_time {
#   seconds: 1700710473
#   nanos: 688120000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11582642439807948930
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11582642439807947781"
# }
#
# create_time {
#   seconds: 1700710474
#   nanos: 624048000
# }
# update_time {
#   seconds: 1700710475
#   nanos: 712727000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-10313997752300399605
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors10313997752300399888"
# }
#
# create_time {
#   seconds: 1700710476
#   nanos: 407070000
# }
# update_time {
#   seconds: 1700710477
#   nanos: 447603000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-18018567221052946792
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors18018567221052947145"
# }
#
# create_time {
#   seconds: 1700710479
#   nanos: 546634000
# }
# update_time {
#   seconds: 1700710480
#   nanos: 703982000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-13298101642623646758
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors13298101642623645201"
# }
#
# create_time {
#   seconds: 1700710482
#   nanos: 41994000
# }
# update_time {
#   seconds: 1700710483
#   nanos: 131549000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4280389400906656219
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4280389400906655846"
# }
#
# create_time {
#   seconds: 1700710484
#   nanos: 634834000
# }
# update_time {
#   seconds: 1700710485
#   nanos: 779766000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15651508679001913033
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15651508679001912392"
# }
#
# create_time {
#   seconds: 1700710487
#   nanos: 693710000
# }
# update_time {
#   seconds: 1700710488
#   nanos: 800507000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4460289548418961682
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4460289548418962597"
# }
#
# create_time {
#   seconds: 1700710491
#   nanos: 442389000
# }
# update_time {
#   seconds: 1700710492
#   nanos: 543939000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-17341738515869130871
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors17341738515869133970"
# }
#
# create_time {
#   seconds: 1700710493
#   nanos: 399185000
# }
# update_time {
#   seconds: 1700710494
#   nanos: 494688000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14218415363449326339
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14218415363449327340"
# }
#
# create_time {
#   seconds: 1700710496
#   nanos: 744760000
# }
# update_time {
#   seconds: 1700710497
#   nanos: 934407000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14112157010691594607
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14112157010691594654"
# }
#
# create_time {
#   seconds: 1700710499
#   nanos: 438900000
# }
# update_time {
#   seconds: 1700710500
#   nanos: 692010000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4470624062301715529
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4470624062301714894"
# }
#
# create_time {
#   seconds: 1700710502
#   nanos: 788273000
# }
# update_time {
#   seconds: 1700710504
#   nanos: 48618000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-4878515322082619630
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors4878515322082620939"
# }
#
# create_time {
#   seconds: 1700710504
#   nanos: 929140000
# }
# update_time {
#   seconds: 1700710506
#   nanos: 163776000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-11228978429647139574
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors11228978429647139389"
# }
#
# create_time {
#   seconds: 1700710507
#   nanos: 317613000
# }
# update_time {
#   seconds: 1700710508
#   nanos: 317468000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-15687599718512149950
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors15687599718512151125"
# }
#
# create_time {
#   seconds: 1700710510
#   nanos: 509261000
# }
# update_time {
#   seconds: 1700710511
#   nanos: 574675000
# }
# success_count: 1
#
# Waiting for operation to complete: projects/861331366245/locations/global/collections/default_collection/dataStores/alphabet-contracts/branches/0/operations/import-documents-14218415363449324099
# error_config {
#   gcs_prefix: "gs://861331366245_us_import_content/errors14218415363449325100"
# }
#
# create_time {
#   seconds: 1700710514
#   nanos: 20548000
# }
# update_time {
#   seconds: 1700710515
#   nanos: 69037000
# }
# success_count: 1

# %% [markdown]
# ## Create a Search Engine
#
# This is used to set the search_tier to enterprise and to enable advanced LLM features.
#
# Enterprise tier is required to get extractive answers from a search query and advanced LLM features are required to sumarize search results.

# %%
def create_engine(project_id: str, location: str, data_store_name: str):
    # Create a client
    client = discoveryengine_v1alpha.EngineServiceClient()
    

    # Initialize request argument(s)
    engine = discoveryengine_v1alpha.Engine()
    engine.display_name = data_store_name
    engine.data_store_ids.append(data_store_name)
    engine.solution_type = "SOLUTION_TYPE_SEARCH" # This can be replaced with "SOLUTION_TYPE_CHAT" to make a chat engine instead
    engine.industry_vertical = "GENERIC"
    engine.search_engine_config.search_tier = "SEARCH_TIER_ENTERPRISE"
    engine.search_engine_config.search_add_ons.append("SEARCH_ADD_ON_LLM")
       

    request = discoveryengine_v1alpha.CreateEngineRequest(
        parent = f"projects/{project_id}/locations/{location}/collections/default_collection",
        engine = engine,
        engine_id = engine.display_name,
    )

    # Make the request
    operation = client.create_engine(request=request)
    response = operation.result(timeout=90)

# %%
create_engine(PROJECT_ID, LOCATION, DATASTORE_ID)
# Out:
# alphabet-contracts

# %% [markdown]
# ## Query your Datastore

# %%
import vertexai
from langchain.llms import VertexAI

# Initialize Vertex AI SDK
vertexai.init(project=PROJECT_ID, location=LLM_LOCATION)

llm = VertexAI(
    model_name='text-bison-32k',
    max_output_tokens=256,
    temperature=0,
    top_p=0.8,
    top_k=40,
    verbose=True,
)

# %%
from langchain.chains import RetrievalQA
from langchain.retrievers import GoogleVertexAISearchRetriever


def get_retrieval_qa(datastore_id):
    search_retriever = GoogleVertexAISearchRetriever(
        project_id=PROJECT_ID,
        location_id=LOCATION,
        data_store_id=datastore_id,
        max_documents=5,
    )
    return RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=search_retriever,
        return_source_documents=True,
        output_key="response"
        
    )

# %%
query = "Who is the CEO of DeepMind?"

result = get_retrieval_qa(DATASTORE_ID)({"query": query})
print(result['response'])
# Out:
#  The CEO of DeepMind is Demis Hassabis.
